# %%
# %load_ext autoreload
# %autoreload 2
import sys
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.inspection import permutation_importance
from sklearn.metrics import balanced_accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer
from sklearn.metrics import plot_confusion_matrix
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
sys.path.append('../')
import shutil
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from src.artifacts import *
import seaborn as sns
import string

# %%
from src.models import *

# %%
df_cc = pd.read_csv('../data/renamed_data.csv')

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# ## data preprocessing

# %%
features = {'SEX':'c',
            'MARRIAGE':'c',
            'EDUCATION':'o',
            'PAY_1':'n',
            'PAY_2':'n',
            'PAY_3':'n',
            'PAY_4':'n',
            'PAY_5':'n',
            'PAY_6':'n',
            'LIMIT_BAL':'n',
            'AGE':'n',
            'BILL_AMT1':'n',
            'BILL_AMT2':'n',
            'BILL_AMT3':'n',
            'BILL_AMT4':'n',
            'BILL_AMT5':'n',
            'BILL_AMT6':'n',
            'PAY_AMT1':'n',
            'PAY_AMT2':'n',
            'PAY_AMT3':'n',
            'PAY_AMT4':'n',
            'PAY_AMT5':'n',
            'PAY_AMT6':'n',
}
target = {
    'default':'c'
}

# %%
df_cc = df_cc[list(features.keys()) + list(target.keys())]

# %%
def Merg(dict1,dict2):
    dict3 = {}
    dict3.update(dict1)
    dict3.update(dict2)
    return dict3

# %%
order_list = ['grad','undergrad','high-school','others']
# df_cc['EDUCATION'] = alphabetize_ordinals(df_cc['EDUCATION'],list_ordinals=order_list)
df_cc = transform_features(df_cc,Merg(features,target))
df_cc = df_cc.sample(500)

# %%
target_list = [x for x in df_cc.columns if x.partition('_')[0] in list(target.keys())]
feature_list = [x for x in df_cc.columns if x not in target_list]

# %%
if os.path.isdir('../results/testing'):
    shutil.rmtree('../results/testing/')
model_info = {
    'model_name':'testing',
    'features':feature_list,
    'targets':target_list,
    'random_state':42,
    'test_size':0.3,
    'parameters' : {'n_estimators': [3, 6,10],
                  'max_depth': [2, 5,10],
                  'min_samples_split': [2, 4, 6]},
    'plot_confusion_matrix':True,
    'learning_curve':True,
    
    
}

train_model(df_cc,model_info)
# Out:
# /Users/pge-prodanovic/Desktop/credit_default/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/pge-prodanovic/Desktop/credit_default/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/pge-prodanovic/Desktop/credit_default/.venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
stop here
# Out:
#   File "<ipython-input-12-a96ba3aab008>", line 1
#     stop here
#          ^
# SyntaxError: invalid syntax

# %%
filename = '../results/testing/trained_model.sav'
clf = pickle.load(open(filename, 'rb'))

# %%
from sklearn.inspection import permutation_importance

# %%
feature_names = df_cc.columns

# %%
X = np.array(df_cc[feature_list])
y = np.array(df_cc[target_list])
test_size = 0.3
random_state = 42

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size,
                                                    random_state=random_state, stratify=y)

# %%
imps = permutation_importance(clf,X_train,y_train,n_repeats=10)
feature_names = df_cc.columns
for i in imps.importances_mean.argsort()[::-1]:
    if imps.importances_mean[i]-2*imps.importances_std[i]>0:
        print(f"{feature_names[i]:<8}" +"   "+  f"{imps.importances_mean[i]:.3f}" f" +/- {imps.importances_std[i]:.3f}")
# Out:
# PAY_1      0.063 +/- 0.017
# PAY_3      0.052 +/- 0.010
# PAY_AMT1   0.043 +/- 0.010
# PAY_AMT2   0.038 +/- 0.012
# BILL_AMT1   0.035 +/- 0.010
# EDUCATION   0.028 +/- 0.010
# PAY_AMT3   0.026 +/- 0.008
# PAY_AMT4   0.026 +/- 0.008
# BILL_AMT6   0.025 +/- 0.011
# PAY_6      0.023 +/- 0.006
# PAY_2      0.023 +/- 0.011
# AGE        0.022 +/- 0.008
# LIMIT_BAL   0.022 +/- 0.005
# PAY_AMT5   0.021 +/- 0.008
# MARRIAGE_single   0.020 +/- 0.007

# %%
fig, ax = plt.subplots(figsize=(12,12))
sorted_idx = imps.importances_mean.argsort()
ax.boxplot(imps.importances[sorted_idx].T,
           vert=False, labels=feature_list)
ax.set_title("Permutation Importance of each feature")
ax.set_ylabel("Features")
fig.tight_layout()
plt.show()
